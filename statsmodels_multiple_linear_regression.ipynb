# %% [markdown]
# # Multiple regression with statsmodels

# %%
from numpy.random import default_rng
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
rng = default_rng()
series_y = pd.Series(rng.standard_normal(size=42))
series_x1 = pd.Series(rng.standard_normal(size=42))
series_x2 = pd.Series(rng.standard_normal(size=42))

# %%
df = pd.DataFrame(
    {
        'x1': series_x1,
        'x2': series_x2,
        'y': series_y
    }
)

# %%
x = sm.add_constant(df[['x1', 'x2']])
y = df['y']

# %%
model = sm.OLS(
    endog=y,
    exog=x,
    missing='drop'
)
results = model.fit()

# %%
df['y_predicted'] = results.predict(x)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.7208
# Date:                Fri, 18 Sep 2020   Prob (F-statistic):              0.493
# Time:                        11:53:20   Log-Likelihood:                -53.527
# No. Observations:                  42   AIC:                             113.1
# Df Residuals:                      39   BIC:                             118.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2554      0.141     -1.811      0.078      -0.540       0.030
# ...

# %%
df = df.sort_values(by=['x1'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.plot(
    df['x1'],
    df['y'],
    marker='.',
    linestyle='None',
    color='#0077bb'
)
ax.plot(
    df['x1'],
    df['y_predicted'],
    marker='.',
    linestyle='None',
    color='#cc3311'
)
ax.set_title(
    label='Regression analysis',
    fontsize=15,
    fontweight='bold'
)
ax.set_xlabel(
    xlabel='X axis label',
    fontsize=12,
    fontweight='bold'
)
ax.set_ylabel(
    ylabel='Y axis label',
    fontsize=12,
    fontweight='bold'
)
# fig.savefig('y_vs_x1.svg', format='svg')
# Out:
# Text(0, 0.5, 'Y axis label')

# %%
df = df.sort_values(by=['x2'])
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.plot(
    df['x2'],
    df['y'],
    marker='.',
    linestyle='None',
    color='#0077bb'
)
ax.plot(
    df['x2'],
    df['y_predicted'],
    marker='.',
    linestyle='None',
    color='#cc3311'
)
ax.set_title(
    label='Regression analysis',
    fontsize=15,
    fontweight='bold'
)
ax.set_xlabel(
    xlabel='X axis label',
    fontsize=12,
    fontweight='bold'
)
ax.set_ylabel(
    ylabel='Y axis label',
    fontsize=12,
    fontweight='bold'
)
# fig.savefig('y_vs_x2.svg', format='svg')
# Out:
# Text(0, 0.5, 'Y axis label')
